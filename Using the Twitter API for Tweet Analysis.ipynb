# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 1.8MB/s ta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x107c199e8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2490383 # Seattle

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#StadiumSeries',
#     'url': 'http://twitter.com/search?q=%23StadiumSeries',
#     'promoted_content': None,
#     'query': '%23StadiumSeries',
#     'tweet_volume': 34409},
#    {'name': '#IntervencionMilitarYA',
#     'url': 'http://twitter.com/search?q=%23IntervencionMilitarYA',
#     'promoted_content': None,
#     'query': '%23IntervencionMilitarYA',
#     'tweet_volume': 254222},
#    {'name': '#LivePD',
#     'url': 'http://twitter.com/search?q=%23LivePD',
#     'promoted_content': None,
#     'query': '%23LivePD',
#     'tweet_volume': 33608},
#    {'name': '#Rainhas2019',
#     'url': 'http://twitter.com/search?q=%23Rainhas2019',
#     'promoted_content': None,
#     'query': '%23Rainhas2019',
#     'tweet_volume': None},
#    {'name': '#HaydiAvni',
#     'url': 'http://twitter.com/search?q=%23HaydiAvni',
#     'promoted_content': None,
#     'query': '%23HaydiAvni',
#     'tweet_volume': None},
#    {'name': 'Matt Murray',
#     'url': 'http://twitter.com/search?q=%22Matt+Murray%22',
#     'promoted_content': None,
#     'query': '%22Matt+Murray%22',
#     'tweet_volume': None},
#    {'name': 'Flyers',
#     'url': 'http://twitter.com/search?q=Flyers',
#     'promoted_content': None,
#     'query': 'Flyers',
#     'tweet_volume': 30692},
#    {'name': 'Holan',
#     'url': 'http://twitter.com/search?q=Holan',
#     'promoted_content': None,
#     'query': 'Holan',
#     'tweet_volume': None},
#    {'name': 'Lisandro López',
#     'url': 'http://twitter.com/search?q=%22Lisandro+L%C3%B3pez%22',
#     'promoted_content': None,
#     'query': '%22Lisandro+L%C3%B3pez%22',
#     'tweet_volume': None},
#    {'name': 'Chris Paul',
#     'url': 'http://twitter.com/search?q=%22Chris+Paul%22',
#     'promoted_content': None,
#     'query': '%22Chris+Paul%22',
#     'tweet_volume': None},
#    {'name': 'Ja Rule',
#     'url': 'http://twitter.com/search?q=%22Ja+Rule%22',
#     'promoted_content': None,
#     'query': '%22Ja+Rule%22',
#     'tweet_volume': 13789},
#    {'name': 'Gritty',
#     'url': 'http://twitter.com/search?q=Gritty',
#     'promoted_content': None,
#     'query': 'Gritty',
#     'tweet_volume': 10325},
#    {'name': 'Pens',
#     'url': 'http://twitter.com/search?q=Pens',
#     'promoted_content': None,
#     'query': 'Pens',
#     'tweet_volume': 13716},
#    {'name': 'Nico Castillo',
#     'url': 'http://twitter.com/search?q=%22Nico+Castillo%22',
#     'promoted_content': None,
#     'query': '%22Nico+Castillo%22',
#     'tweet_volume': None},
#    {'name': 'Independiente',
#     'url': 'http://twitter.com/search?q=Independiente',
#     'promoted_content': None,
#     'query': 'Independiente',
#     'tweet_volume': 92835},
#    {'name': 'Licha',
#     'url': 'http://twitter.com/search?q=Licha',
#     'promoted_content': None,
#     'query': 'Licha',
#     'tweet_volume': 12563},
#    {'name': '純粋度',
#     'url': 'http://twitter.com/search?q=%E7%B4%94%E7%B2%8B%E5%BA%A6',
#     'promoted_content': None,
#     'query': '%E7%B4%94%E7%B2%8B%E5%BA%A6',
#     'tweet_volume': None},
#    {'name': 'PJ Tucker',
#     'url': 'http://twitter.com/search?q=%22PJ+Tucker%22',
#     'promoted_content': None,
#     'query': '%22PJ+Tucker%22',
#     'tweet_volume': None},
#    {'name': 'Golden State',
#     'url': 'http://twitter.com/search?q=%22Golden+State%22',
#     'promoted_content': None,
#     'query': '%22Golden+State%22',
#     'tweet_volume': None},
#    {'name': 'Pelicans',
#     'url': 'http://twitter.com/search?q=Pelicans',
#     'promoted_content': None,
#     'query': 'Pelicans',
#     'tweet_volume': 11988},
#    {'name': 'Zucc',
#     'url': 'http://twitter.com/search?q=Zucc',
#     'promoted_content': None,
#     'query': 'Zucc',
#     'tweet_volume': None},
#    {'name': 'Claude Giroux',
#     'url': 'http://twitter.com/search?q=%22Claude+Giroux%22',
#     'promoted_content': None,
#     'query': '%22Claude+Giroux%22',
#     'tweet_volume': None},
#    {'name': 'Habs',
#     'url': 'http://twitter.com/search?q=Habs',
#     'promoted_content': None,
#     'query': 'Habs',
#     'tweet_volume': 12581},
#    {'name': 'Arias',
#     'url': 'http://twitter.com/search?q=Arias',
#     'promoted_content': None,
#     'query': 'Arias',
#     'tweet_volume': 30922},
#    {'name': 'Simmonds',
#     'url': 'http://twitter.com/search?q=Simmonds',
#     'promoted_content': None,
#     'query': 'Simmonds',
#     'tweet_volume': None},
#    {'name': '#TrajeDesastre',
#     'url': 'http://twitter.com/search?q=%23TrajeDesastre',
#     'promoted_content': None,
#     'query': '%23TrajeDesastre',
#     'tweet_volume': None},
#    {'name': '#IDontUnderstandPeopleWho',
#     'url': 'http://twitter.com/search?q=%23IDontUnderstandPeopleWho',
#     'promoted_content': None,
#     'query': '%23IDontUnderstandPeopleWho',
#     'tweet_volume': None},
#    {'name': '#私の嫌いな食べ物晒す見た人もする',
#     'url': 'http://twitter.com/search?q=%23%E7%A7%81%E3%81%AE%E5%AB%8C%E3%81%84%E3%81%AA%E9%A3%9F%E3%81%B9%E7%89%A9%E6%99%92%E3%81%99%E8%A6%8B%E3%81%9F%E4%BA%BA%E3%82%82%E3%81%99%E3%82%8B',
#     'promoted_content': None,
#     'query': '%23%E7%A7%81%E3%81%AE%E5%AB%8C%E3%81%84%E3%81%AA%E9%A3%9F%E3%81%B9%E7%89%A9%E6%99%92%E3%81%99%E8%A6%8B%E3%81%9F%E4%BA%BA%E3%82%82%E3%81%99%E3%82%8B',
#     'tweet_volume': 21278},
#    {'name': '#YoEstoyConAMLO',
#     'url': 'http://twitter.com/search?q=%23YoEstoyConAMLO',
#     'promoted_content': None,
#     'query': '%23YoEstoyConAMLO',
#     'tweet_volume': 14070},
#    {'name': '#GazetaNaFolia',
#     'url': 'http://twitter.com/search?q=%23GazetaNaFolia',
#     'promoted_content': None,
#     'query': '%23GazetaNaFolia',
#     'tweet_volume': None},
#    {'name': '#Saint黒澤Snow',
#     'url': 'http://twitter.com/search?q=%23Saint%E9%BB%92%E6%BE%A4Snow',
#     'promoted_content': None,
#     'query': '%23Saint%E9%BB%92%E6%BE%A4Snow',
#     'tweet_volume': 12703},
#    {'name': '#最後に七瀬へ伝えたいこと',
#     'url': 'http://twitter.com/search?q=%23%E6%9C%80%E5%BE%8C%E3%81%AB%E4%B8%83%E7%80%AC%E3%81%B8%E4%BC%9D%E3%81%88%E3%81%9F%E3%81%84%E3%81%93%E3%81%A8',
#     'promoted_content': None,
#     'query': '%23%E6%9C%80%E5%BE%8C%E3%81%AB%E4%B8%83%E7%80%AC%E3%81%B8%E4%BC%9D%E3%81%88%E3%81%9F%E3%81%84%E3%81%93%E3%81%A8',
#     'tweet_volume': None},
#    {'name': '#YoMeVoy',
#     'url': 'http://twitter.com/search?q=%23YoMeVoy',
#     'promoted_content': None,
#     'query': '%23YoMeVoy',
#     'tweet_volume': None},
#    {'name': '#kimimachi',
#     'url': 'http://twitter.com/search?q=%23kimimachi',
#     'promoted_content': None,
#     'query': '%23kimimachi',
#     'tweet_volume': 15422},
#    {'name': '#あなたの心の純粋さ',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E5%BF%83%E3%81%AE%E7%B4%94%E7%B2%8B%E3%81%95',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E5%BF%83%E3%81%AE%E7%B4%94%E7%B2%8B%E3%81%95',
#     'tweet_volume': None},
#    {'name': '#wicked',
#     'url': 'http://twitter.com/search?q=%23wicked',
#     'promoted_content': None,
#     'query': '%23wicked',
#     'tweet_volume': None},
#    {'name': '#PITvsPHI',
#     'url': 'http://twitter.com/search?q=%23PITvsPHI',
#     'promoted_content': None,
#     'query': '%23PITvsPHI',
#     'tweet_volume': None},
#    {'name': '#ASAPNatinTo',
#     'url': 'http://twitter.com/search?q=%23ASAPNatinTo',
#     'promoted_content': None,
#     'query': '%23ASAPNatinTo',
#     'tweet_volume': None},
#    {'name': '#RainhadasRainhas2019',
#     'url': 'http://twitter.com/search?q=%23RainhadasRainhas2019',
#     'promoted_content': None,
#     'query': '%23RainhadasRainhas2019',
#     'tweet_volume': None},
#    {'name': '#MannKiBaat',
#     'url': 'http://twitter.com/search?q=%23MannKiBaat',
#     'promoted_content': None,
#     'query': '%23MannKiBaat',
#     'tweet_volume': 11122},
#    {'name': '#اوقفوا_القصمان_عن_اكل_الجراد',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%88%D9%82%D9%81%D9%88%D8%A7_%D8%A7%D9%84%D9%82%D8%B5%D9%85%D8%A7%D9%86_%D8%B9%D9%86_%D8%A7%D9%83%D9%84_%D8%A7%D9%84%D8%AC%D8%B1%D8%A7%D8%AF',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%88%D9%82%D9%81%D9%88%D8%A7_%D8%A7%D9%84%D9%82%D8%B5%D9%85%D8%A7%D9%86_%D8%B9%D9%86_%D8%A7%D9%83%D9%84_%D8%A7%D9%84%D8%AC%D8%B1%D8%A7%D8%AF',
#     'tweet_volume': None},
#    {'name': '#のど自慢',
#     'url': 'http://twitter.com/search?q=%23%E3%81%AE%E3%81%A9%E8%87%AA%E6%85%A2',
#     'promoted_content': None,
#     'query': '%23%E3%81%AE%E3%81%A9%E8%87%AA%E6%85%A2',
#     'tweet_volume': None},
#    {'name': '#DomingoDetremuraSDV',
#     'url': 'http://twitter.com/search?q=%23DomingoDetremuraSDV',
#     'promoted_content': None,
#     'query': '%23DomingoDetremuraSDV',
#     'tweet_volume': None},
#    {'name': '#FixMyLife',
#     'url': 'http://twitter.com/search?q=%23FixMyLife',
#     'promoted_content': None,
#     'query': '%23FixMyLife',
#     'tweet_volume': None},
#    {'name': '#FeastDedicatedToGod',
#     'url': 'http://twitter.com/search?q=%23FeastDedicatedToGod',
#     'promoted_content': None,
#     'query': '%23FeastDedicatedToGod',
#     'tweet_volume': None},
#    {'name': '#RollercoasterAMovie',
#     'url': 'http://twitter.com/search?q=%23RollercoasterAMovie',
#     'promoted_content': None,
#     'query': '%23RollercoasterAMovie',
#     'tweet_volume': None},
#    {'name': '#HOUvsGSW',
#     'url': 'http://twitter.com/search?q=%23HOUvsGSW',
#     'promoted_content': None,
#     'query': '%23HOUvsGSW',
#     'tweet_volume': None},
#    {'name': '#HariDilan',
#     'url': 'http://twitter.com/search?q=%23HariDilan',
#     'promoted_content': None,
#     'query': '%23HariDilan',
#     'tweet_volume': None},
#    {'name': '#صباح_الاحد',
#     'url': 'http://twitter.com/search?q=%23%D8%B5%D8%A8%D8%A7%D8%AD_%D8%A7%D9%84%D8%A7%D8%AD%D8%AF',
#     'promoted_content': None,
#     'query': '%23%D8%B5%D8%A8%D8%A7%D8%AD_%D8%A7%D9%84%D8%A7%D8%AD%D8%AF',
#     'tweet_volume': None},
#    {'name': '#SpiritAwards',
#     'url': 'http://twitter.com/search?q=%23SpiritAwards',
#     'promoted_content': None,
#     'query': '%23SpiritAwards',
#     'tweet_volume': 41227}],
#   'as_of': '2019-02-24T05:02:15Z',
#   'created_at': '2019-02-24T04:55:20Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#wiad19', 'url': 'http://twitter.com/search?q=%23wiad19', 'promoted_content': None, 'query': '%23wiad19', 'tweet_volume': None}, {'name': '#BuhariIsWinning', 'url': 'http://twitter.com/search?q=%23BuhariIsWinning', 'promoted_content': None, 'query': '%23BuhariIsWinning', 'tweet_volume': 21229}, {'name': '#NigeriaDecides2019', 'url': 'http://twitter.com/search?q=%23NigeriaDecides2019', 'promoted_content': None, 'query': '%23NigeriaDecides2019', 'tweet_volume': 538641}, {'name': '#ElectionDay', 'url': 'http://twitter.com/search?q=%23ElectionDay', 'promoted_content': None, 'query': '%23ElectionDay', 'tweet_volume': 143021}, {'name': 'Feinstein', 'url': 'http://twitter.com/search?q=Feinstein', 'promoted_content': None, 'query': 'Feinstein', 'tweet_volume': 189679}, {'name': 'Lagos', 'url': 'http://twitter.com/search?q=Lagos', 'promoted_content': None, 'query': 'Lagos', 'tweet_volume': 213007}, {'name': '#PyCascades2019', 'url': 'http://twitter.com/search?q=%23PyCascades2019', 'promoted_content': None, 'query': '%23PyCascades2019', 'tweet_volume': None}, {'name': 'Messi', 'url': 'http://twitter.com/search?q=Messi', 'promoted_content': None, 'query': 'Messi', 'tweet_volume': 710152}, {'name': 'Matt Murray', 'url': 'http://twitter.com/search?q=%22Matt+Murray%22', 'promoted_content': None, 'query': '%22Matt+Murray%22', 'tweet_volume': None}, {'name': 'Flyers', 'url': 'http://twitter.com/search?q=Flyers', 'promoted_content': None, 'query': 'Flyers', 'tweet_volume': 30892}, {'name': 'Ja Rule', 'url': 'http://twitter.com/search?q=%22Ja+Rule%22', 'promoted_content': None, 'query': '%22Ja+Rule%22', 'tweet_volume': 14378}, {'name': 'Gritty', 'url': 'http://twitter.com/search?q=Gritty', 'promoted_content': None, 'query': 'Gritty', 'tweet_volume': 10392}, {'name': 'Pens', 'url': 'http://twitter.com/search?q=Pens', 'promoted_content': None, 'query': 'Pens', 'tweet_volume': 13783}, {'name': 'Zucc', 'url': 'http://twitter.com/search?q=Zucc', 'promoted_content': None, 'query': 'Zucc', 'tweet_volume': None}, {'name': 'Claude Giroux', 'url': 'http://twitter.com/search?q=%22Claude+Giroux%22', 'promoted_content': None, 'query': '%22Claude+Giroux%22', 'tweet_volume': None}, {'name': 'PJ Tucker', 'url': 'http://twitter.com/search?q=%22PJ+Tucker%22', 'promoted_content': None, 'query': '%22PJ+Tucker%22', 'tweet_volume': None}, {'name': 'Simmonds', 'url': 'http://twitter.com/search?q=Simmonds', 'promoted_content': None, 'query': 'Simmonds', 'tweet_volume': None}, {'name': 'Texas Tech', 'url': 'http://twitter.com/search?q=%22Texas+Tech%22', 'promoted_content': None, 'query': '%22Texas+Tech%22', 'tweet_volume': None}, {'name': 'Draymond', 'url': 'http://twitter.com/search?q=Draymond', 'promoted_content': None, 'query': 'Draymond', 'tweet_volume': 14280}, {'name': 'Keith Urban', 'url': 'http://twitter.com/search?q=%22Keith+Urban%22', 'promoted_content': None, 'query': '%22Keith+Urban%22', 'tweet_volume': None}, {'name': 'Zach LaVine', 'url': 'http://twitter.com/search?q=%22Zach+LaVine%22', 'promoted_content': None, 'query': '%22Zach+LaVine%22', 'tweet_volume': None}, {'name': 'Hanley Ramirez', 'url': 'http://twitter.com/search?q=%22Hanley+Ramirez%22', 'promoted_content': None, 'query': '%22Hanley+Ramirez%22', 'tweet_volume': None}, {'name': 'Faried', 'url': 'http://twitter.com/search?q=Faried', 'promoted_content': None, 'query': 'Faried', 'tweet_volume': None}, {'name': 'Chávez', 'url': 'http://twitter.com/search?q=Ch%C3%A1vez', 'promoted_content': None, 'query': 'Ch%C3%A1vez', 'tweet_volume': 148908}, {'name': 'The Rockets', 'url': 'http://twitter.com/search?q=%22The+Rockets%22', 'promoted_content': None, 'query': '%22The+Rockets%22', 'tweet_volume': 12699}, {'name': 'No Harden', 'url': 'http://twitter.com/search?q=%22No+Harden%22', 'promoted_content': None, 'query': '%22No+Harden%22', 'tweet_volume': None}, {'name': 'Cullen', 'url': 'http://twitter.com/search?q=Cullen', 'promoted_content': None, 'query': 'Cullen', 'tweet_volume': None}, {'name': ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#StadiumSeries",
#     "url": "http://twitter.com/search?q=%23StadiumSeries",
#     "promoted_content": null,
#     "query": "%23StadiumSeries",
#     "tweet_volume": 34409
#    },
#    {
#     "name": "#LivePD",
#     "url": "http://twitter.com/search?q=%23LivePD",
#     "promoted_content": null,
#     "query": "%23LivePD",
#     "tweet_volume": 33608
#    },
#    {
#     "name": "Matt Murray",
#     "url": "http://twitter.com/search?q=%22Matt+Murray%22",
#     "promoted_content": null,
#     "query": "%22Matt+Murray%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Flyers",
#     "url": "http://twitter.com/search?q=Flyers",
#     "promoted_content": null,
#     "query": "Flyers",
#     "tweet_volume": 30692
#    },
#    {
#     "name": "Ja Rule",
#     "url": "http://twitter.com/search?q=%22Ja+Rule%22",
#     "promoted_content": null,
#     "query": "%22Ja+Rule%22",
#     "tweet_volume": 13789
#    },
#    {
#     "name": "#IDontUnderstandPeopleWho",
#     "url": "http://twitter.com/search?q=%23IDontUnderstandPeopleWho",
#     "promoted_content": null,
#     "query": "%23IDontUnderstandPeopleWho",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gritty",
#     "url": "http://twitter.com/search?q=Gritty",
#     "promoted_content": null,
#     "query": "Gritty",
#     "tweet_volume": 10325
#    },
#    {
#     "name": "Pens",
#     "url": "http://twitter.com/search?q=Pens",
#     "promoted_content": null,
#     "query": "Pens",
#     "tweet_volume": 13716
#    },
#    {
#     "name": "#wicked",
#     "url": "http://twitter.com/search?q=%23wicked",
#     "promoted_content": null,
#     "query": "%23wicked",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PITvsPHI",
#     "url": "http://twitter.com/search?q=%23PITvsPHI",
#     "promoted_content": null,
#     "query": "%23PITvsPHI",
#     "tweet_volume": null
#    },
#    {
#     "name": "Claude Giroux",
#     "url": "http://twitter.com/search?q=%22Claude+Giroux%22",
#     "promoted_content": null,
#     "query": "%22Claude+Giroux%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Zucc",
#     "url": "http://twitter.com/search?q=Zucc",
#     "promoted_content": null,
#     "query": "Zucc",
#     "tweet_volume": null
#    },
#    {
#     "name": "PJ Tucker",
#     "url": "http://twitter.com/search?q=%22PJ+Tucker%22",
#     "promoted_content": null,
#     "query": "%22PJ+Tucker%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Simmonds",
#     "url": "http://twitter.com/search?q=Simmonds",
#     "promoted_content": null,
#     "query": "Simmonds",
#     "tweet_volume": null
#    },
#    {
#     "name": "Texas Tech",
#     "url": "http://twitter.com/search?q=%22Texas+Tech%22",
#     "promoted_content": null,
#     "query": "%22Texas+Tech%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Draymond",
#     "url": "http://twitter.com/search?q=Draymond",
#     "promoted_content": null,
#     "query": "Draymond",
#     "tweet_volume": 14062
#    },
#    {
#     "name": "Keith Urban",
#     "url": "http://twitter.com/search?q=%22Keith+Urban%22",
#     "promoted_content": null,
#     "query": "%22Keith+Urban%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Zach LaVine",
#     "url": "http://twitter.com/search?q=%22Zach+LaVine%22",
#     "promoted_content": null,
#     "query": "%22Zach+LaVine%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Faried",
#     "url": "http://twitter.com/search?q=Faried",
#     "promoted_content": null,
#     "query": "Faried",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hanley Ramirez",
#     "url": "http://twitter.com/search?q=%22Hanley+Ramirez%22",
#     "promoted_content": null,
#     "query": "%22Hanley+Ramirez%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ch\u00e1vez",
#     "url": "http://twitter.com/search?q=Ch%C3%A1vez",
#     "promoted_content": null,
#     "query": "Ch%C3%A1vez",
#     "tweet_volume": 148121
#    },
#    {
#     "name": "The Rockets",
#     "url": "http://twitter.com/search?q=%22The+Rockets%22",
#     "promoted_content": null,
#     "query": "%22The+Rockets%22",
#     "tweet_volume": 12554
#    },
#    {
#     "name": "No Harden",
#     "url": "http://twitter.com/search?q=%22No+Harden%22",
#     "promoted_content": null,
#     "query": "%22No+Harden%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cullen",
#     "url": "http://twitter.com/search?q=Cullen",
#     "promoted_content": null,
#     "query": "Cullen",
#     "tweet_volume": null
#    },
#    {
#     "name": "KOMH",
#     "url": "http://twitter.com/search?q=KOMH",
#     "promoted_content": null,
#     "query": "KOMH",
#     "tweet_volume": null
#    },
#    {
#     "name": "Letang",
#     "url": "http://twitter.com/search?q=Letang",
#     "promoted_content": null,
#     "query": "Letang",
#     "tweet_volume": null
#    },
#    {
#     "name": "Voracek",
#     "url": "http://twitter.com/search?q=Voracek",
#     "promoted_content": null,
#     "query": "Voracek",
#     "tweet_volume": null
#    },
#    {
#     "name": "Garrett Gilbert",
#     "url": "http://twitter.com/search?q=%22Garrett+Gilbert%22",
#     "promoted_content": null,
#     "query": "%22Garrett+Gilbert%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Brook Lopez",
#     "url": "http://twitter.com/search?q=%22Brook+Lopez%22",
#     "promoted_content": null,
#     "query": "%22Brook+Lopez%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mettenberger",
#     "url": "http://twitter.com/search?q=Mettenberger",
#     "promoted_content": null,
#     "query": "Mettenberger",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rozier",
#     "url": "http://twitter.com/search?q=Rozier",
#     "promoted_content": null,
#     "query": "Rozier",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FixMyLife",
#     "url": "http://twitter.com/search?q=%23FixMyLife",
#     "promoted_content": null,
#     "query": "%23FixMyLife",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RollercoasterAMovie",
#     "url": "http://twitter.com/search?q=%23RollercoasterAMovie",
#     "promoted_content": null,
#     "query": "%23RollercoasterAMovie",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Boruto",
#     "url": "http://twitter.com/search?q=%23Boruto",
#     "promoted_content": null,
#     "query": "%23Boruto",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HOUvsGSW",
#     "url": "http://twitter.com/search?q=%23HOUvsGSW",
#     "promoted_content": null,
#     "query": "%23HOUvsGSW",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GhostAdventures",
#     "url": "http://twitter.com/search?q=%23GhostAdventures",
#     "promoted_content": null,
#     "query": "%23GhostAdventures",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LAMH",
#     "url": "http://twitter.com/search?q=%23LAMH",
#     "promoted_content": null,
#     "query": "%23LAMH",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RiosSoto",
#     "url": "http://twitter.com/search?q=%23RiosSoto",
#     "promoted_content": null,
#     "query": "%23RiosSoto",
#     "tweet_volume": null
#    },
#    {
#     "name": "#kubball",
#     "url": "http://twitter.com/search?q=%23kubball",
#     "promoted_content": null,
#     "query": "%23kubball",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SpiritAwards",
#     "url": "http://twitter.com/search?q=%23SpiritAwards",
#     "promoted_content": null,
#     "query": "%23SpiritAwards",
#     "tweet_volume": 41227
#    },
#    {
#     "name": "#SaturdayNight",
#     "url": "http://twitter.com/search?q=%23SaturdayNight",
#     "promoted_content": null,
#     "query": "%23SaturdayNight",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LoveOnTheMenu",
#     "url": "http://twitter.com/search?q=%23LoveOnTheMenu",
#     "promoted_content": null,
#     "query": "%23LoveOnTheMenu",
#     "tweet_volume": 10307
#    },
#    {
#     "name": "#WreckEm",
#     "url": "http://twitter.com/search?q=%23WreckEm",
#     "promoted_content": null,
#     "query": "%23WreckEm",
#     "tweet_volume": null
#    },
#    {
#     "name": "#grownwiththeclique",
#     "url": "http://twitter.com/search?q=%23grownwiththeclique",
#     "promoted_content": null,
#     "query": "%23grownwiththeclique",
#     "tweet_volume": null
#    },
#    {
#     "name": "#48Hours",
#     "url": "http://twitter.com/search?q=%2348Hours",
#     "promoted_content": null,
#     "query": "%2348Hours",
#     "tweet_volume": null
#    },
#    {
#     "name": "#IQuestionMySanityWhen",
#     "url": "http://twitter.com/search?q=%23IQuestionMySanityWhen",
#     "promoted_content": null,
#     "query": "%23IQuestionMySanityWhen",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Svengoolie",
#     "url": "http://twitter.com/search?q=%23Svengoolie",
#     "promoted_content": null,
#     "query": "%23Svengoolie",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DALatUTA",
#     "url": "http://twitter.com/search?q=%23DALatUTA",
#     "promoted_content": null,
#     "query": "%23DALatUTA",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NBAonABC",
#     "url": "http://twitter.com/search?q=%23NBAonABC",
#     "promoted_content": null,
#     "query": "%23NBAonABC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MeTVBuckRogers",
#     "url": "http://twitter.com/search?q=%23MeTVBuckRogers",
#     "promoted_content": null,
#     "query": "%23MeTVBuckRogers",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2019-02-24T05:02:15Z",
#   "created_at": "2019-02-24T04:55:20Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['seattle'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','seattle']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #FixMyLife,#最後に七瀬へ伝えたいこと,Habs,Lisandro López,#IntervencionMilitarYA,#Rainhas2019,#IDontUnderstandPeopleWho,Claude Giroux,Ja Rule,#GazetaNaFolia,Gritty,#صباح_الاحد,#LivePD,#TrajeDesastre,Zucc,Golden State,#HOUvsGSW,PJ Tucker,#SpiritAwards,#RainhadasRainhas2019,#FeastDedicatedToGod,#のど自慢,#اوقفوا_القصمان_عن_اكل_الجراد,#HaydiAvni,#PITvsPHI,Pelicans,Simmonds,#wicked,#YoEstoyConAMLO,#HariDilan,純粋度,#kimimachi,#StadiumSeries,#DomingoDetremuraSDV,#RollercoasterAMovie,Nico Castillo,Matt Murray,Arias,Pens,#Saint黒澤Snow,Independiente,#あなたの心の純粋さ,Licha,#ASAPNatinTo,Flyers,Chris Paul,#私の嫌いな食べ物晒す見た人もする,#YoMeVoy,#MannKiBaat,Holan
# ('----------', 'us')
# Hanley Ramirez,#FixMyLife,#WreckEm,#DALatUTA,#NBAonABC,#kubball,#IDontUnderstandPeopleWho,Claude Giroux,Ja Rule,Zach LaVine,Texas Tech,Gritty,#GhostAdventures,Keith Urban,#LivePD,Mettenberger,Faried,#LoveOnTheMenu,Zucc,Cullen,#SaturdayNight,#HOUvsGSW,PJ Tucker,Letang,#SpiritAwards,#Boruto,#RiosSoto,#PITvsPHI,Simmonds,#wicked,Rozier,#48Hours,Draymond,#Svengoolie,#MeTVBuckRogers,#StadiumSeries,#RollercoasterAMovie,Matt Murray,No Harden,#grownwiththeclique,Pens,KOMH,#LAMH,The Rockets,Garrett Gilbert,Voracek,Brook Lopez,#IQuestionMySanityWhen,Chávez,Flyers
# ('----------', 'seattle')
# Hanley Ramirez,#FixMyLife,Feinstein,#WreckEm,#kubball,#IDontUnderstandPeopleWho,Claude Giroux,Texas Tech,Ja Rule,Zach LaVine,Gritty,#PyCascades2019,Keith Urban,#LivePD,#GhostAdventures,Faried,#LoveOnTheMenu,Zucc,Cullen,#SaturdayNight,#HOUvsGSW,PJ Tucker,#ElectionDay,#SpiritAwards,#Boruto,#RiosSoto,#PITvsPHI,Simmonds,#wicked,#48Hours,Draymond,#Svengoolie,#VoteNotFight,#BuhariIsWinning,#NigeriaDecides2019,#StadiumSeries,#RollercoasterAMovie,Matt Murray,No Harden,Messi,#grownwiththeclique,Pens,KOMH,#LAMH,The Rockets,#wiad19,#IQuestionMySanityWhen,Chávez,Lagos,Flyers

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and seattle'))
print((trends_set['seattle'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'Gritty', '#PITvsPHI', '#LivePD', 'Simmonds', 'Pens', '#wicked', '#FixMyLife', 'Zucc', '#HOUvsGSW', '#IDontUnderstandPeopleWho', 'PJ Tucker', 'Flyers', 'Claude Giroux', 'Ja Rule', '#SpiritAwards', '#StadiumSeries', '#RollercoasterAMovie', 'Matt Murray'}
# ('==========', 'intersection of us and seattle')
# {'Hanley Ramirez', '#FixMyLife', '#WreckEm', '#kubball', '#IDontUnderstandPeopleWho', 'Claude Giroux', 'Ja Rule', 'Zach LaVine', 'Texas Tech', 'Gritty', '#GhostAdventures', 'Keith Urban', '#LivePD', 'Faried', '#LoveOnTheMenu', 'Zucc', 'Cullen', '#SaturdayNight', '#HOUvsGSW', 'PJ Tucker', '#SpiritAwards', '#Boruto', '#RiosSoto', '#PITvsPHI', 'Simmonds', '#wicked', '#48Hours', 'Draymond', '#Svengoolie', '#StadiumSeries', '#RollercoasterAMovie', 'Matt Murray', 'No Harden', '#grownwiththeclique', 'Pens', 'KOMH', '#LAMH', 'The Rockets', '#IQuestionMySanityWhen', 'Chávez', 'Flyers'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#machinelearning' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Sun Feb 24 05:36:45 +0000 2019', 'id': 1099543632573620224, 'id_str': '1099543632573620224', 'text': 'RT @mind_sync: What problems Mindsync solves:\n- Continually increasing demand and lack of experts\n- Complexity in integration and adaptatio…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'mind_sync', 'name': 'mindsync', 'id': 1065976672359464961, 'id_str': '1065976672359464961', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://thechrischua.com" rel="nofollow">DS-retweet</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 983629872365944833, 'id_str': '983629872365944833', 'name': 'Chris Chua', 'screen_name': 'theChrisChua', 'location': 'Singapore', 'description': 'On a #MicrosoftExcel and #Python for Data Science learning journey. Sharing news on #DataScience #ML #NLP #DL #NeuralNetworks', 'url': 'https://t.co/3TcEk7ku73', 'entities': {'url': {'urls': [{'url': 'https://t.co/3TcEk7ku73', 'expanded_url': 'https://code.thechrischua.com', 'display_url': 'code.thechrischua.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1634, 'friends_count': 206, 'listed_count': 56, 'created_at': 'Tue Apr 10 08:56:51 +0000 2018', 'favourites_count': 4, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 58424, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1050295525742792704/1mFbJ8EN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1050295525742792704/1mFbJ8EN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/983629872365944833/1539245009', 'profile_link_color': '002EA7', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Feb 09 15:44:01 +0000 2019', 'id': 1094260638325575680, 'id_str': '1094260638325575680', 'text': 'What problems Mindsync solves:\n- Continually increasing demand and lack of experts\n- Complexity in integration and… https://t.co/2NCmVrrljf', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/2NCmVrrljf', 'expanded_url': 'https://twitter.com/i/web/status/1094260638325575680', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1065976672359464961, 'id_str': '1065976672359464961', 'name': 'mindsync', 'screen_name': 'mind_sync', 'location': 'United Kingdom', 'description': 'Mindsync is a decentralized, community-driven AI platform where everyone can participate in the growing AI market: order / create & share AI services as a value', 'url': 'https://t.co/j9rtKBiFBw', 'entities': {'url': {'urls': [{'url': 'https://t.co/j9rtKBiFBw', 'expanded_url': 'https://minds ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 78

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @mind_sync: What problems Mindsync solves:\n- Continually increasing demand and lack of experts\n- Complexity in integration and adaptatio…',
#  'RT @hawkfx: "It’s hard to tell what is true and what is not in this era, since scientists and professionals sometimes fail to reach a conse…',
#  'RT @mind_sync: What MindSync is and How it Works?\nRead more at Medium: https://t.co/t3gAWwFYAr\n#mindsync #AI #Datascience #machinelearning…',
#  'RT @mind_sync: What MindSync is and How it Works?\nRead more at Medium: https://t.co/t3gAWwFYAr\n#mindsync #AI #Datascience #machinelearning…',
#  'RT @MikeQuindazzi: #AI wants to decide if #humans are innocent or guilty &gt;&gt;&gt; @MikeQuindazzi &gt;&gt;&gt; #MachineLearning #NLP #DeepLearning #Machin…',
#  '"It’s hard to tell what is true and what is not in this era, since scientists and professionals sometimes fail to r… https://t.co/aS8b9Sf5s5',
#  'RT @mind_sync: What problems Mindsync solves:\n- Continually increasing demand and lack of experts\n- Complexity in integration and adaptatio…',
#  "So we won our first hackathon. The track was AI/ML and 'WeUseTabs' finished third.\n#ArtificialIntelligence… https://t.co/78wtGinzLq",
#  'RT @MuvMeInc: Half of US #Startups expect their next funding source to be #VentureCapital &gt;&gt;&gt;@SVB_Financial via @MikeQuindazzi &gt;&gt;&gt; #Machine…',
#  '63% of CEOs Believe Artificial Intelligence Will Have Even More Impact On The World Than The Internet Revolution… https://t.co/pepZtDvAke',
#  'RT @VizWorld: Top 7 Skills You Need To Have As A Data Analyst https://t.co/98d7QxFRFW #Learning #DeepLearning #MachineLearning #AI https://…',
#  'RT @iamChuckRussell: #TechTopics: The best online Python courses 2019 - PCWorld\n\n#pyton #python #pythonic #ml #machinelearning\n\nRead More H…',
#  'RT @IainLJBrown: Artificial Intelligence in Modern Warfare Market Report Disclosing Latest Trends and Advancement 2019 to 2023 - Honest Ver…',
#  'RT @andi_staub: [sophisticated but worth reading]\n\nHandling Imbalanced Datasets in #DeepLearning\n\n#AI #ArtificialIntelligence #DataScience…',
#  'RT @andi_staub: [sophisticated but worth reading]\n\nHandling Imbalanced Datasets in #DeepLearning\n\n#AI #ArtificialIntelligence #DataScience…',
#  'RT @MikeQuindazzi: #AI reaching #human-like precision and reliability on high complexity tasks &gt;&gt;&gt; #PwC via @MikeQuindazzi &gt;&gt;&gt; #FinTech #Ch…',
#  'RT @Fisher85M: Solutions of #machinelearning!\n\n[@jblefevre60]\n#AI #ML #DL #disruption #bigdata #banking #fintech #IoT #startup #SmartCity #…',
#  'RT @yharishy: How @ncbn wins big ticket clients(investors) even with a weak product like #AP ?\n1. Always embarking on a new route that no o…',
#  'Using Amazon #Sagemaker for Scalable #MachineLearning Training • https://t.co/xrRh8oBHAj @filestack',
#  'Walmart Labs (@WalmartLabs ) Acqui-hires Bengaluru-based #machinelearning Startup @dataturkss… https://t.co/McFGYECpyu',
#  'RT @KirkDBorne: How Do You Win the #DataScience Wars? You Cheat By Doing The Necessary Pre-work: https://t.co/yty1TqNxRK #abdsc by @schmarz…',
#  'The Complete TensorFlow Masterclass: Machine Learning Models https://t.co/tpzWaoLWs8  #machinelearning #ad   @machinelearnflx',
#  'RT @KirkDBorne: Descriptive Analytics, #PrescriptiveAnalytics, and #PredictiveAnalytics for Customer Experience: https://t.co/fP89H6Wep5 by…',
#  'RT @KirkDBorne: &gt;@Accelerite @ShareInsights_ 3.0 Accelerates the Benefits of #AWS #DataLakes for #BigData Analytics: https://t.co/wnUzj2kCh…',
#  'RT @KirkDBorne: Take a look at @Accelerite @ShareInsights_ 3.0 – the No-code Analytics Platform for #AWS #DataLakes, includes data wranglin…',
#  'RT @KirkDBorne: #AI is Not Magic – It’s Time to Demystify and Apply: https://t.co/zC33bntMN6 by @robdthomas \n\n#BigData #DataScience #Machin…',
#  'RT @machine_ml: RT @StrategyBird: RT @hudson_chatbots: RT @Paula_Piccard "How do you describe what #AI can do? #Infographic\nv/ @Fisher85M #…',
#  '📒The Internet of Things : A Very Short Story [#Infographic] ◆ Follow: https://t.co/R9YJ3qlrBQ ◆ #Wearable #Sensors… https://t.co/bGRIyXahjm',
#  'Understanding Why MATLAB Is Best Suited For Deep Learning https://t.co/57gQfaLMR8 #DeepLearning #MachineLearning… https://t.co/hBGjC10cLU',
#  'RT @grattongirl: 10 #EmergingTechnologies advancing in the #Enterprise in 2019 &gt;&gt;&gt; @MikeQuindazzi &gt;&gt;&gt; #AI #IoT #BigData #MachineLearning #D…',
#  'Top 4 advantages of #AI and #Robotics in #Healthcare:\n- Easier and quicker to access\n- Better treatment recommendat… https://t.co/TRvoi1eOFf',
#  'RT @RaktimBanerjee: Walmart Labs (WalmartLabsInd ) #Acquihires Bengaluru-based #Startup dataturkss https://t.co/vRYWoS7X83 #MachineLearning…',
#  'RT @dhruvashastri12: Discussion about Speech Tagging and words find out neighbouring probable matching words and form vectors at @WTMAhmeda…',
#  'RT @grattongirl: 10 #EmergingTechnologies advancing in the #Enterprise in 2019 &gt;&gt;&gt; @MikeQuindazzi &gt;&gt;&gt; #AI #IoT #BigData #MachineLearning #D…',
#  'RT @nsh67463788: Enhance Your Business’s Customer Experience With Machine Learning #AI #MachineLearning #CustomerExperience https://t.co/5B…',
#  'RT @MikeTamir: Obtaining Insights From Data: Optimizing an NBA Career https://t.co/LA30mLVTwP #AI #DeepLearning #MachineLearning #DataScien…',
#  'RT @WorldTrendsInfo: What are the 7 outcomes for #AI? #Infographic\n\n#IoT #BigData #MachineLearning #DataScience #Robotics #innovation #star…',
#  'Walmart Labs (WalmartLabsInd ) #Acquihires Bengaluru-based #Startup dataturkss https://t.co/vRYWoS7X83 #MachineLearning Walmart',
#  'RT @TelliusData: “With Tellius automated data discovery, we’ve cut down the time to analyze data and present answers to executives and depa…',
#  'RT @IBMDataScience: Attention students &amp; faculty: \nWatson Studio Desktop is now available to you at no charge! 🆓\nCheck it out here: https:/…',
#  'RT @KirkDBorne: #AI is Not Magic – It’s Time to Demystify and Apply: https://t.co/zC33bntMN6 by @robdthomas \n\n#BigData #DataScience #Machin…',
#  'RT @Fisher85M: Adaptive Circular Cities {Infographic}\n\n#SmartCity #IoT #5G #CyberSecurity #infosec #BigData @Fisher85M #GreenLiving #Machin…',
#  'RT @LouisColumbus: AI Is Not Replacing People in Digital Marketing https://t.co/fxl3hKQSzS &lt;- Insightful survey from IAB Europe and Xaxis s…',
#  'RT @LouisColumbus: AI Is Not Replacing People in Digital Marketing https://t.co/fxl3hKQSzS &lt;- Insightful survey from IAB Europe and Xaxis s…',
#  'RT @indianweb2: Walmart Labs (@WalmartLabsInd ) #Acquihires Bengaluru-based #Startup @dataturkss https://t.co/u3U4LHOVcs #MachineLearning @…',
#  "RT @PD_MobileApps: BT to strip Huawei equipment from 4G network by 2021, won't use it in 5G core - CNET: #machinelearning #ai #iot copy: @m…",
#  "BT to strip Huawei equipment from 4G network by 2021, won't use it in 5G core - CNET: #machinelearning #ai #iot cop… https://t.co/zQtusVXBuv",
#  'Walmart Labs (@WalmartLabsInd ) #Acquihires Bengaluru-based #Startup @dataturkss https://t.co/u3U4LHOVcs #MachineLearning @Walmart',
#  'RT @LouisColumbus: AI Is Not Replacing People in Digital Marketing https://t.co/fxl3hKQSzS &lt;- Insightful survey from IAB Europe and Xaxis s…',
#  'Someone just signed up for our AI and Machine Learning webinar. Space is limited, grab a spot here:… https://t.co/P9So3vYSOH',
#  "RT @sbmeunier: Natural Language Processing and it's Applications Translation, Summarization, Sentiment Analysis, Classification, Speech Pro…",
#  'RT @iamChuckRussell: #TechTopics: The best online Python courses 2019 - PCWorld\n\n#pyton #python #pythonic #ml #machinelearning\n\nRead More H…',
#  'RT @iamChuckRussell: #TechTopics: The best online Python courses 2019 - PCWorld\n\n#pyton #python #pythonic #ml #machinelearning\n\nRead More H…',
#  '.@Lucidworks #CEO talks up ‘data experiences’\n\nhttps://t.co/15fQvdbuGF\n\n#AI #ArtificialIntelligence… https://t.co/3SpRoV9LxD',
#  'RT @MortlockReinard: Perceptron\u200a—\u200aDeep Learning Basics\n#AI #machinelearning #BigData #IoT #deeplearning #mathematics \n https://t.co/2Xp7Wjm…',
#  'RT @RetweetedRajeev: How did a bit of artificial intelligence turn racist or sexist? It’s possible the staff designing it had some blind sp…',
#  'RT @yharishy: How @ncbn wins big ticket clients(investors) even with a weak product like #AP ?\n1. Always embarking on a new route that no o…',
#  'RT @zeekayinfo3: @Swim #OpenSources Its #MachineLearning Platform for #EdgeComputing\nhttps://t.co/PcWosNvJK6',
#  'Watch a self-driving car obey police hand signals https://t.co/VmPg7o5C7F #Learning #SelfDrivingCar #AI… https://t.co/6B1KvsaM6M',
#  'RT @SpirosMargaris: How #ArtificialIntelligence and #MachineLearning \n\nhelp Fight against #CyberAttacks \n\nhttps://t.co/6s118P674K @analytic…',
#  'RT @KirkDBorne: Graph Database use cases reveal interesting, insightful, and intrinsic relationships in data: https://t.co/5QoJaKml2Q by @J…',
#  'RT @WorldTrendsInfo: What are the 7 outcomes for #AI? #Infographic\n\n#IoT #BigData #MachineLearning #DataScience #Robotics #innovation #star…',
#  'RT @KirkDBorne: Take a look at @Accelerite @ShareInsights_ 3.0 – the No-code Analytics Platform for #AWS #DataLakes, includes data wranglin…',
#  'RT @hsianghui: The Essential Data Science Venn Diagram #data #datascience #machinelearning #ai #deeplearning https://t.co/FqOj85B4OY',
#  'RT @MortlockReinard: Weekend Takeaway: It’s all about AI these days\n#AI #machinelearning #BigData #IoT #deeplearning #mathematics #FutureTe…',
#  'RT @WTMAhmedabad: #GoogleSearch example for Imbalanced data and how that can be optimized with #DeepLearning by @thelogicalkoan #MachineLea…',
#  'RT @VizWorld: "It’s hard to tell what is true and what is not in this era, since scientists and professionals sometimes fail to reach a con…',
#  'RT @WTMAhmedabad: #GoogleSearch example for Imbalanced data and how that can be optimized with #DeepLearning by @thelogicalkoan #MachineLea…',
#  'RT @WorldTrendsInfo: What are the 7 outcomes for #AI? #Infographic\n\n#IoT #BigData #MachineLearning #DataScience #Robotics #innovation #star…',
#  'RT @cellofoodiegeek: Great feedback, interaction &amp; appreciation on the project presented by the Thinking Machines team on Using AI &amp; Satell…',
#  'RT @MortlockReinard: AI Weekly: Experts say OpenAI’s controversial model is a potential threat to society and science\n#AI #machinelearning…',
#  'RT @shubhsdubey: Which algorithm to use????\n#MachineLearning #DataScience @analyticbridge https://t.co/fdHSrR0FyM',
#  'RT @StanleyEpstein: #Machinelearning as a solution &gt;&gt;&gt;&gt; #infographic #AI #ML #DL #disruption #bigdata #banking #fintech #IoT #startup #Smar…',
#  'RT @cellofoodiegeek: Great feedback, interaction &amp; appreciation on the project presented by the Thinking Machines team on Using AI &amp; Satell…',
#  'RT @MortlockReinard: Microsoft employees protest: HoloLens for good, not war\n#AI #machinelearning #BigData #IoT #Microsoft #HoloLens #Futur…',
#  'RT @livexsoftware: Enterprise AI: Data Analytics, Data Science and Machine Learning\n#AI #machinelearning #BigData #IoT #deeplearning #mathe…',
#  'RT @MikeQuindazzi: 7 amazing ways #AI is transforming #Healthcare &gt;&gt;&gt; @wef via @MikeQuindazzi &gt;&gt;&gt; #ArtificialIntelligence #IoT #FutureofWor…',
#  'RT @GrataSoftware: What cloud computing can learn from good BBQ https://t.co/Cfv6wzEyMc\n#devops #iot #bigdata #microservices #bbq #infoworl…',
#  'RT @livexsoftware: Enterprise AI: Data Analytics, Data Science and Machine Learning\n#AI #machinelearning #BigData #IoT #deeplearning #mathe…',
#  "RT @Ronald_vanLoon: Join me &amp; 1700 industry leaders today at @Nasscom Technology &amp; Leadership Forum 2019 opening keynote. 'technologies of…",
#  'What are the 7 outcomes for #AI? #Infographic\n\n#IoT #BigData #MachineLearning #DataScience #Robotics #innovation… https://t.co/6sEtIPpFVV',
#  'RT @KirkDBorne: Descriptive Analytics, #PrescriptiveAnalytics, and #PredictiveAnalytics for Customer Experience: https://t.co/fP89H6Wep5 by…',
#  "RT @nordicinst: Don't Fight the Robots. Tax Them.. #AI #MachineLearning #dataresponsible https://t.co/6aO3VSjJin",
#  'RT @rbukralia: How elite investors use artificial intelligence and machine learning to gain an edge - CNN https://t.co/2ql5myW8Ma  #AI #ML…',
#  "RT @startupshireme: RT @kimberl87759219: Top story: @ravikikan: 'Anatomy Of a #DataScientist \n\nvia @ravikikan #MachineLearning #Robots #Inf…",
#  'RT @MikeQuindazzi: Unpacking #AutonomousVehicles and the #EmergingTechnologies enabling #SelfDriving &gt;&gt;&gt; #CBInsights via @MikeQuindazzi &gt;&gt;&gt;…',
#  "RT @startupshireme: RT @kimberl87759219: Top story: @ravikikan: 'Anatomy Of a #DataScientist \n\nvia @ravikikan #MachineLearning #Robots #Inf…",
#  'RT @Ronald_vanLoon: These Dancing #Drones just broke a world record\nby @nowthisnews |\n\n#ArtificialIntelligence #AI #Robotics #Robots #DeepL…',
#  'How Artificial Intelligence and Machine Learning help Fight against Cyber Attacks https://t.co/mmy4RydQu1… https://t.co/rN2NQW98A0',
#  'RT @shubhsdubey: Which algorithm to use????\n#MachineLearning #DataScience @analyticbridge https://t.co/fdHSrR0FyM',
#  'RT @melissablive: Artificial Intelligence in Saudi Arabia https://t.co/fNkhamfl1j #DeepLearning #dataresponsible #MachineLearning https://t…',
#  'RT @ipfconline1: #MachineLearning for Everyone\n(In simple words. With real-world examples.)\n\nhttps://t.co/ROvpIr1TnF  v/ @vas3k\n#AI #DeepLe…',
#  'RT @MikeQuindazzi: This #FutureofWork Jobs Report predicts #AI &amp; #Robotic technologies of #Industry40 will increasingly take over tasks fro…',
#  'RT @KirkDBorne: Graph Database use cases reveal interesting, insightful, and intrinsic relationships in data: https://t.co/5QoJaKml2Q by @J…',
#  'RT @Sexypriya15: I need a fucking man who make satisfying...😉 @Nicolette_Shea \nMsg me who has large n strong dick 😘\n#Pennsylvania #Hufflepu…',
#  'RT @Ronald_vanLoon: Big Impacts of #AI, #MachineLearning, and #DeepLearning in business\nby @Techrepublic |\n\n#ML #ArtificialIntelligence #DL…',
#  'RT @melissablive: Artificial Intelligence in Saudi Arabia https://t.co/fNkhamfl1j #DeepLearning #dataresponsible #MachineLearning https://t…',
#  'RT @shubhsdubey: Which algorithm to use????\n#MachineLearning #DataScience @analyticbridge https://t.co/fdHSrR0FyM',
#  "RT @ipfconline1: Natural Language Processing and it's Applications\n👇\nTranslation, Summarization, Sentiment Analysis, Classification, Speech…",
#  'RT @soumyasanto: How can organization can build AI-ready #workforce for the #futureofwork \nhttps://t.co/Pa3YDXfFp1\n\n&gt;&gt; Gr8 overview from @M…']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sun Feb 24 05:36:45 +0000 2019",
#  "id": 1099543632573620224,
#  "id_str": "1099543632573620224",
#  "text": "RT @mind_sync: What problems Mindsync solves:\n- Continually increasing demand and lack of experts\n- Complexity in integration and adaptatio\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "mind_sync",
#     "name": "mindsync",
#     "id": 1065976672359464961,
#     "id_str": "1065976672359464961",
#     "indices": [
#      3,
#      13
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"https://thechrischua.com\" rel=\"nofollow\">DS-retweet</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 983629872365944833,
#   "id_str": "983629872365944833",
#   "name": "Chris Chua",
#   "screen_name": "theChrisChua",
#   "location": "Singapore",
#   "description": "On a #MicrosoftExcel and #Python for Data Science learning journey. Sharing news on #DataScience #ML #NLP #DL #NeuralNetworks",
#   "url": "https://t.co/3TcEk7ku73",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/3TcEk7ku73",
#       "expanded_url": "https://code.thechrischua.com",
#       "display_url": "code.thechrischua.com",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 1634,
#   "friends_count": 206,
#   "listed_count": 56,
#   "created_at": "Tue Apr 10 08:56:51 +0000 2018",
#   "favourites_count": 4,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 58424,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1050295525742792704/1mFbJ8EN_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1050295525742792704/1mFbJ8EN_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/983629872365944833/1539245009",
#   "profile_link_color": "002EA7",
#   "profile_sidebar_border_color": "000000",
#   "profile_sidebar_fill_color": "000000",
#   "profile_text_color": "000000",
#   "profile_use_background_image": false,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sat Feb 09 15:44:01 +0000 2019",
#   "id": 1094260638325575680,
#   "id_str": "1094260638325575680",
#   "text": "What problems Mindsync solves:\n- Continually increasing demand and lack of experts\n- Complexity in integration and\u2026 https://t.co/2NCmVrrljf",
#   "truncated": true,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/2NCmVrrljf",
#      "expanded_url": "https://twitter.com/i/web/status/1094260638325575680",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       116,
#       139
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 1065976672359464961,
#    "id_str": "1065976672359464961",
#    "name": "mindsync",
#    "screen_name": "mind_sync",
#    "location": "United Kingdom",
#    "description": "Mindsync is a decentralized, community-driven AI platform where everyone can participate in the growing AI market: order / create & share AI services as a value",
#    "url": "https://t.co/j9rtKBiFBw",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/j9rtKBiFBw",
#        "expanded_url": "https://mindsync.ai",
#        "display_url": "mindsync.ai",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 4269,
#    "friends_count": 0,
#    "listed_count": 6,
#    "created_at": "Fri Nov 23 14:33:38 +0000 2018",
#    "favourites_count": 33,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 90,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1067706034918236160/CULJBUSH_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1067706034918236160/CULJBUSH_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1065976672359464961/1546787833",
#    "profile_link_color": "209FF5",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 95,
#   "favorite_count": 120,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 95,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 95
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

#print(json.dumps(status_texts[0:5], indent=1))
#print(json.dumps(screen_names[0:5], indent=1)) 
#print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "mind_sync",
#  "hawkfx",
#  "mind_sync",
#  "MikeQuindazzi",
#  "MikeQuindazzi"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 65), ('and', 33), ('#AI', 25), ('to', 19), ('#MachineLearning', 18), ('in', 15), ('a', 13), ('the', 13), ('is', 12), ('for', 12)]
#
# [('MikeQuindazzi', 11), ('KirkDBorne', 6), ('Fisher85M', 4), ('MortlockReinard', 4), ('dataturkss', 3), ('Ronald_vanLoon', 3), ('mind_sync', 2), ('VizWorld', 2), ('Accelerite', 2), ('ShareInsights_', 2)]
#
# [('AI', 29), ('MachineLearning', 21), ('machinelearning', 13), ('IoT', 11), ('BigData', 10), ('DeepLearning', 8), ('ArtificialIntelligence', 7), ('DataScience', 6), ('ML', 4), ('Infographic', 4)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     65
# and                  |     33
# #AI                  |     25
# to                   |     19
# #MachineLearning     |     18
# in                   |     15
# a                    |     13
# the                  |     13
# is                   |     12
# for                  |     12
#
#     Screen Name      | Count
# ****************************************
# MikeQuindazzi        |     11
# KirkDBorne           |      6
# Fisher85M            |      4
# MortlockReinard      |      4
# dataturkss           |      3
# Ronald_vanLoon       |      3
# mind_sync            |      2
# VizWorld             |      2
# Accelerite           |      2
# ShareInsights_       |      2
#
#       Hashtag        | Count
# ****************************************
# AI                   |     29
# MachineLearning      |     21
# machinelearning      |     13
# IoT                  |     11
# BigData              |     10
# DeepLearning         |      8
# ArtificialIntelligence |      7
# DataScience          |      6
# ML                   |      4
# Infographic          |      4

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#   261   |  MikeQuindazzi  | RT @MikeQuindazzi: 7 amazing ways #AI is transform
#         |                 | ing #Healthcare &gt;&gt;&gt; @wef via @MikeQuindaz
#         |                 | zi &gt;&gt;&gt; #ArtificialIntelligence #IoT #FutureofWor…
#   130   |  MikeQuindazzi  | RT @MikeQuindazzi: #AI wants to decide if #humans
#         |                 | are innocent or guilty &gt;&gt;&gt; @MikeQuindazzi
#         |                 |  &gt;&gt;&gt; #MachineLearning #NLP #DeepLearning #Machin…
#   114   |  MikeQuindazzi  | RT @MikeQuindazzi: #AI reaching #human-like precis
#         |                 | ion and reliability on high complexity tasks &gt;&
#         |                 | gt;&gt; #PwC via @MikeQuindazzi &gt;&gt;&gt; #FinTech #Ch…
#   95    |    mind_sync    | RT @mind_sync: What problems Mindsync solves:\- Co
#         |                 | ntinually increasing demand and lack of experts\-
#         |                 | Complexity in integration and adaptatio…
#   77    |   KirkDBorne    | RT @KirkDBorne: How Do You Win the #DataScience Wa
#         |                 | rs? You Cheat By Doing The Necessary Pre-work: htt
#         |                 | ps://t.co/yty1TqNxRK #abdsc by @schmarz…
#   77    |    Fisher85M    | RT @Fisher85M: Solutions of #machinelearning!\\[@j
#         |                 | blefevre60]\#AI #ML #DL #disruption #bigdata #bank
#         |                 | ing #fintech #IoT #startup #SmartCity #…
#   77    |    Fisher85M    | RT @Fisher85M: Adaptive Circular Cities {Infograph
#         |                 | ic}\\#SmartCity #IoT #5G #CyberSecurity #infosec #
#         |                 | BigData @Fisher85M #GreenLiving #Machin…
#   68    |    mind_sync    | RT @mind_sync: What MindSync is and How it Works?\
#         |                 | Read more at Medium: https://t.co/t3gAWwFYAr\#mind
#         |                 | sync #AI #Datascience #machinelearning…
#   48    | Ronald_vanLoon  | RT @Ronald_vanLoon: These Dancing #Drones just bro
#         |                 | ke a world record\by @nowthisnews |\\#ArtificialIn
#         |                 | telligence #AI #Robotics #Robots #DeepL…
#   44    |  MikeQuindazzi  | RT @MikeQuindazzi: This #FutureofWork Jobs Report
#         |                 | predicts #AI &amp; #Robotic technologies of #Indus
#         |                 | try40 will increasingly take over tasks fro…
